# %% [markdown]
# # IMAGE PROCESSING
# - Translation
# - Rotation
# - Resizing
# - Flipping
# - Cropping
# - ColorSpaces

# %% [markdown]
# ## Translation
# Translation is the shifting of an image along the X and Y axis.<br>
# Using translation, we can shift an image up, down,left, or right, <br>
# along with any combination of the above

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('d.png')
# cv2.imshow('img', img)
plt.imshow(img)
plt.show()

# %% [markdown]
# ''' Translatios shift the image towards Right, left and diagonally
#     cv2 has function wrapAffine which takes a translation matrix
#
#            T = | 1  0  Tx |  Tx - shift along X-axis
#                | 0  1  Ty |  Ty - shift along Y-axis
#
# '''

# %%
(h, w) = img.shape[:2]           # Finding Height and Width
(q_h, q_w) =(int(h/4), int(w/4))#  Calculating Quarter Height and Quarter Width

# %% [markdown]
# ### Creating translation matrix

# %%
m = np.float32([[1, 0, q_w],
                [0, 1, q_h]])
print(m)
# Out:
# [[ 1.  0. 87.]
#  [ 0.  1. 57.]]

# %% [markdown]
# ### Performing Translation

# %%
translated = imutils.translate(img, 25, -75)
plt.imshow(translated)
plt.show()
# cv2.imshow('translated', translated)

# # Displaying Output

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Rotation
# Rotation is exactly what it sounds like: rotating an image by some angle θ.<br>
# θ is used to represent by how many degrees we are rotating the image.

# %%
img = cv2.imread('d.png')
cv2.imshow('img', img)

# %% [markdown]
# ### Calculation Center Points

# %%
h, w = img.shape[:2]
(x, y) = (int(img.shape[1]/2), int(img.shape[0]/2))

# %% [markdown]
# ''' just like in translation we have a matrix used in rotation called rotation matrix
#
#            | cos0  -sin0 |
#        m = | sin0   cos0 |
#
#        0(theta) = angle of ratation
#      cv2.getRotationMartrix2D((center_x, center_y), angle_of_rotation, scale)
#
# '''

# %% [markdown]
# ## Performing Rotation

# %%
rotate = cv2.getRotationMatrix2D((x, y), 45, 1)
rotation = cv2.warpAffine(img, rotate, (w, h))

plt.imshow(rotation)
plt.show()
# cv2.imshow('rotated', rotation)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Easy Method to perform rotation

# %%
# !pip3 install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.3.tar.gz (17 kB)
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.3-py3-none-any.whl size=25856 sha256=4e2dbd6427d30a2888a6033aa614a0933fea41ad7c90cc6c45cf6840f828fe16
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\27\4d\3a\6dcdf7c3ebc87bf1ae013d96c9cf060ccfe334bb5ee769f377
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.3

# %%
import imutils
img = cv2.imread('d.png')
rot = imutils.rotate(img, 270)

plt.imshow(rot)
plt.show()
# cv2.imshow("Rotated by 180 Degrees", rot)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Resizing

# %%
img = cv2.imread('light.png')
plt.imshow(img)
plt.show()
print(img.shape)
# cv2.imshow('original', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-b1678a2d73ba> in <module>
#       1 img = cv2.imread('light.png')
# ----> 2 plt.imshow(img)
#       3 plt.show()
#       4 print(img.shape)
#       5 # cv2.imshow('original', img)
#
# c:\users\hp\appdata\local\conda\conda\envs\env\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2711         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2712         url=url, **({"data": data} if data is not None else {}),
# -> 2713         **kwargs)
#    2714     sci(__ret)
#    2715     return __ret
#
# c:\users\hp\appdata\local\conda\conda\envs\env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1429     def inner(ax, *args, data=None, **kwargs):
#    1430         if data is None:
# -> 1431             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1432
#    1433         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\hp\appdata\local\conda\conda\envs\env\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5517                               resample=resample, **kwargs)
#    5518
# -> 5519         im.set_data(X)
#    5520         im.set_alpha(alpha)
#    5521         if im.get_clip_path() is None:
#
# c:\users\hp\appdata\local\conda\conda\envs\env\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     696                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     697             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 698                             "float".format(self._A.dtype))
#     699
#     700         if self._A.ndim == 3 and self._A.shape[-1] == 1:
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
g = img.copy()
height = 300
width  = 300

resize = cv2.resize(img, (height, width))
plt.imshow(resize)
plt.show()
# cv2.imshow('resized', resize)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
print(resize.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-c3c0ff7dcdac> in <module>
# ----> 1 g = img.copy()
#       2 height = 300
#       3 width  = 300
#       4
#       5 resize = cv2.resize(img, (height, width))
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %% [markdown]
# ## Flipping
# We can flip an image around either the x or
# y axis, or even both

# %%
image = cv2.imread('d.png')
plt.imshow(image)
plt.show()
# cv2.imshow('original', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# Argument: <br>
# 1 means Flipped <b> Horizontally</b><br>
# 0 means Flipped <b> Vertically</b><br>
# 3 means Flipped <b> Horizontally & Vertically</b>

# %%
flipped = cv2.flip(image, 0)
plt.imshow(flipped)
plt.show()
# cv2.imshow("Flipped Horizontally", flipped)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Cropping

# %%
img= cv2.imread('d.png')
plt.imshow(img)
plt.show()

# cv2.imshow('original ',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
''' Here img takes four argument 
      Y1  -- Up  
      Y2  -- Down
      X1  -- Left
      X2  -- Right

'''
print('')

# %%
cropped = img[20:130, 230:340]     # Cropping the Specified Portion of the Image
plt.imshow(cropped)
plt.show()
# cv2.imshow('crop', cropped)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## ColorSpaces

# %%
image = cv2.imread('light.png')
# image = cv2.cvtColor(image, cvt.COLOR_BGR2RBG)
# cv2.imshow("Original", image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray", gray)
cv2.waitKey(0)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2.imshow("HSV", hsv)

lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
cv2.imshow("LAB", lab)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Feature Detection in OpenCV

# %% [markdown]
# # 1. Smoothing And Blurring
# - Averaging
# - Gaussian
# - Median
# - Bilateral

# %% [markdown]
# Blurring means that each pixel in the image is mixed in with its surrounding pixel intensities.<br>
# This “mixture” of pixels in a neighborhood becomes our blurred pixel

# %% [markdown]
# ## Gaussian Blur
# Blurring function needs a kernel
# <img src = 'blur.jpg' height ='300' width  = '400'>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('d.png')
plt.imshow(img)
plt.show()
# cv2.imshow('img', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
gaussian = cv2.GaussianBlur(img, (7,7), 0)

plt.imshow(gaussian)
plt.show()

# cv2.imshow('gaussian', gaussian)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# # 2. THRESHOLDING
# <h3>Thresholding is the binarization of an image.</h3><br>
# In general, we seek to convert a grayscale image to a binary image, where the pixels are either 0 or 255.<br>
# A simple thresholding example would be selecting a pixel value p,<br>
# and then setting all pixel intensities less than p to zero, <br>
# and all pixel values greater than p to 255.<br>
# In this way,we are able to create a binary representation of the image.

# %% [markdown]
# ''' Thresholding is a act of converting an image to binary form
#
#     cv2.threshold(img, Threshold_Value, Max_value, Threshold_Type)
#     here Threshold_value is the value above that every value becomes 255 (White) and
#     everything below becomes 0 (Black)
#
# '''

# %%
''' Loading Image and Converting it into Grayscale '''

img = cv2.imread('d.png',0)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
print(img)

# cv2.imshow('img', img)

''' Performing Thresholding '''
print('====================================================================================================')
ret, threshold = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
print(ret)
plt.imshow(threshold)
plt.show()

print(threshold)
# cv2.imshow('threshold', threshold)

# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# [[[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [239 239 239]
#   [236 236 236]
#   [232 232 232]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [239 239 239]
#   [238 238 238]
#   [235 235 235]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [240 240 240]
#   [238 238 238]
#   [235 235 235]]
#
#  ...
#
#  [[240 240 240]
#   [240 240 240]
#   [240 240 240]
#   ...
#   [237 237 237]
#   [237 237 237]
#   [237 237 237]]
#
#  [[241 241 241]
#   [241 241 241]
#   [241 241 241]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[241 241 241]
#   [241 241 241]
#   [241 241 241]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]]
# ====================================================================================================
# 127.0
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# # 3. Canny Edge Detection
# Canny Edge Detection is a popular edge detection algorithm.<br>
# It was developed by John F. Canny<br>
# Edge detection is useful for finding boundaries of objects in an image<br>
#
# <h3>cv2.Canny(img, min_value, max_value)</h3>

# %%
img = cv2.imread('d.png',0)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# img = cv2.cvtColor(img, cv2.COLOR_RBG2GRAY)
# cv2.imshow('img', img)
plt.imshow(img)
plt.show()

''' Performing Edge Detection
'''

edge = cv2.Canny(img, 70, 120)
# cv2.imshow('edge', edge)
edge = cv2.cvtColor(edge, cv2.COLOR_BGR2RGB)
plt.imshow(edge)
plt.show()
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# Any gradient value larger than threshold2 is considered to be an edge.<br>
# Any value below threshold1 is considered not to be an edge. <br>
# Values in between threshold1 and threshold2 are either classified as edges or non-edges
# based on how their intensities are “connected”.

# %%
''' Edge Detection With Blurring '''
a=img.copy()
a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
gaussian = cv2.GaussianBlur(a, (7,7), 0)
edge = cv2.Canny(gaussian, 130, 220)
edge = cv2.cvtColor(edge, cv2.COLOR_BGR2RGB)
#plt.imshow(edge)
#plt.show()
cv2.imshow('edge', edge)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 4. Contours
# OpenCV provides methods to find “curves” in an image, called contours.<br>
# A contour is a curve of points, with no gaps in the curve, having same color or intensity <br>
# Contours are extremely useful for such things as shape approximation and analysis.

# %% [markdown]
# ''' cv2.findContours(img, retrieval_mode, approximation_mode)
#
#     retrieval_mode : external - stores only extrnal contours
#                      list     - stores all contours
#
#     approximation method : chain approx none - stores all boundary points
#                            chain approx simple - stores only start and ending points
# '''

# %%
img = cv2.imread('hands.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

gaussian = cv2.GaussianBlur(img, (7,7), 0)

cv2.imshow('org', img)

# Finding Edges
edge = cv2.Canny(gray, 90, 330)
cv2.imshow('edge', edge)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Finding Contours

# %%
''' Returning only External Contours '''
contours, hierarchy = cv2.findContours(edge, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
print('Numbers of contours are : ', len(contours))


cv2.drawContours(img, contours, -1, (255,0, 0), 3)

plt.imshow(img)
plt.show();

#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# Numbers of contours are :  2
